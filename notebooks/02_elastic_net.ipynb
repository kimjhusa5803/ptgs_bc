# %% [markdown]
# # 02 — Elastic-net baseline
#
# Run and characterize the **elastic-net** PTGS (the reference method) on the target trait: nested-CV performance, sparsity (nonzero genes), and stability across folds.

# %%
import ptgs_bc as ptgs
# TODO: develop this stage against the package API.
